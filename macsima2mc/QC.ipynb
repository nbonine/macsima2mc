# %%
from skimage.metrics import structural_similarity as ssi
from pathlib import Path
from ome_types import from_tiff

# %%
indir="C:/Users/VictorP/Desktop/Postdoc projects/Tsomakidou_Tanevski_Schapiro/staged/new_staging/patient_3693/roi-001/raw"

# %%
indir=Path(indir)
indir
# Out:
# WindowsPath('C:/Users/VictorP/Desktop/Postdoc projects/Tsomakidou_Tanevski_Schapiro/staged/new_staging/patient_3693/roi-001/raw')

# %%
cycles=list(indir.glob("*.tif*"))
cycles
# Out:
# [WindowsPath('C:/Users/VictorP/Desktop/Postdoc projects/Tsomakidou_Tanevski_Schapiro/staged/new_staging/patient_3693/roi-001/raw/corr_cycle-001-src-B-roi-1-markers-DAPI-01__Blank__Blank__Blank-filters-DAPI__AF-647-Cy5__AF-750-Cy7__Atto550.ome.tiff'),
#  WindowsPath('C:/Users/VictorP/Desktop/Postdoc projects/Tsomakidou_Tanevski_Schapiro/staged/new_staging/patient_3693/roi-001/raw/corr_cycle-002-src-S-roi-1-markers-DAPI-02__CD31__CD45__CD8-filters-DAPI__AF-750-Cy7__AF-647-Cy5__Atto550.ome.tiff'),
#  WindowsPath('C:/Users/VictorP/Desktop/Postdoc projects/Tsomakidou_Tanevski_Schapiro/staged/new_staging/patient_3693/roi-001/raw/corr_cycle-003-src-S-roi-1-markers-DAPI-03__CD21__CD4__Sma-filters-DAPI__Atto550__AF-647-Cy5__AF-750-Cy7.ome.tiff'),
#  WindowsPath('C:/Users/VictorP/Desktop/Postdoc projects/Tsomakidou_Tanevski_Schapiro/staged/new_staging/patient_3693/roi-001/raw/corr_cycle-004-src-S-roi-1-markers-DAPI-04__CD20__HLA__PDPN-filters-DAPI__AF-750-Cy7__AF-647-Cy5__Atto550.ome.tiff'),
# ...

# %%
ome=from_tiff(cycles[0])

# %%
ome
# Out:
# OME(
#    images=[<49 field_type>],
#    creator='ome_types 0.5.2 / python version- 3.12.9',
# )

# %%
 ome.images[0].pixels.planes
# Out:
# [Plane(
#     the_z=0,
#     the_t=0,
#     the_c=0,
#     exposure_time=7.0,
#     position_x=0.0,
#     position_x_unit='mm',
#     position_y=0.0,
#     position_y_unit='mm',
#     position_z=0.0,
#  ),
#  Plane(
#     the_z=0,
#     the_t=0,
#     the_c=1,
#     exposure_time=450.0,
#     position_x=0.0,
#     position_x_unit='mm',
#     position_y=0.0,
#     position_y_unit='mm',
#     position_z=0.0,
#  ),
#  Plane(
#     the_z=0,
#     the_t=0,
#     the_c=2,
#     exposure_time=275.0,
#     position_x=0.0,
#     position_x_unit='mm',
#     position_y=0.0,
#     position_y_unit='mm',
#     position_z=0.0,
#  ),
#  Plane(
#     the_z=0,
#     the_t=0,
#     the_c=3,
#     exposure_time=450.0,
#     position_x=0.0,
#     position_x_unit='mm',
#     position_y=0.0,
#     position_y_unit='mm',
#     position_z=0.0,
#  )]
